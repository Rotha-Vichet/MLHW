# %% [markdown]
# <a href="https://colab.research.google.com/github/Rotha-Vichet/MLHW/blob/main/Simple%26MultipleRegressionTask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task : Find out the answer of the below three error code
#
# 1. Simple Linear-MSE,Absolute error,R^2
# 2. Repeat the same for Multiple LR
# 3. Graph for Multiple

# %% [markdown]
# **Simple Linear Regression**
#
# ---

# %%
#library
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

import pandas as pd
import matplotlib.pyplot as plt  
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/Rotha-Vichet/MLHW/main/AMC.csv') 
dataset.head(10)
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2022-01-03  27.420000  28.129999  26.420000  26.520000  26.520000  26740900
# 1  2022-01-04  26.670000  26.670000  24.639999  25.490000  25.490000  33347900
# 2  2022-01-05  25.170000  25.299999  22.360001  22.750000  22.750000  45172100
# 3  2022-01-06  22.959999  23.770000  20.799999  22.459999  22.459999  59112700
# 4  2022-01-07  23.610001  24.299999  22.440001  22.990000  22.990000  49481000
# 5  2022-01-10  22.420000  22.870001  21.250000  22.780001  22.780001  37784000
# 6  2022-01-11  22.400000  23.750000  22.090000  22.790001  22.790001  36063800
# 7  2022-01-12  22.860001  23.360001  22.049999  22.719999  22.719999  27472100
# 8  2022-01-13  22.650000  23.150000  20.530001  20.660000  20.660000  41005000
# 9  2022-01-14  20.330000  21.080000  19.510000  20.570000  20.570000  56996600

# %%
# select the variable (x-EU_Sales, y - Global_Sales)
x_variable = ['Close']  
y_variable = ['Volume']   

x = np.array(dataset[x_variable]).reshape(-1, 1)
y = np.array(dataset[y_variable]).reshape(-1, 1)
print(x.shape)
print(y.shape)
# Out:
# (102, 1)
# (102, 1)

# %%
# split the dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2) # 80% training , 20% test

print('x_train:', x_train.shape)
print('y_train:', y_train.shape)
print('x_test:', x_test.shape)
print('y_test:', y_test.shape)
# Out:
# x_train: (81, 1)
# y_train: (81, 1)
# x_test: (21, 1)
# y_test: (21, 1)

# %%
#build a model(simpleLinear)
Lin_reg = LinearRegression()

# %%
#train the model using the training sets
model = Lin_reg.fit(x_train, y_train)

# %%
Q0 = model.intercept_
Q1= model.coef_
print("Q0 : ",Q0)
print("Q1 : ",Q1)
# Out:
# Q0 :  [11479777.56650442]
# Q1 :  [[2062091.56661252]]

# %% [markdown]
# y_hat = 0.06 + 1.88x

# %%
# Make predictions using the testing set
y_pred = model.predict(x_test)

# %%
# The coefficients / slope
print('Coefficients / slope : \n',model.coef_)
# Out:
# Coefficients / slope :
#  [[2062091.56661252]]

# %%
# The mean squared error
print('Mean squared error: %.2f' % mean_squared_error(y_test,y_pred))
# Out:
# Mean squared error: 1781316027175865.25

# %%
# Mean Absolute Error

print("Mean absolute Error : %.2f" % mean_absolute_error(y_test,y_pred))
# Out:
# Mean absolute Error : 21768278.64

# %%
# The coefficient of determination R^2
print('Coefficient of determination: %.2f' % r2_score(y_test,y_pred))
# Out:
# Coefficient of determination: 0.12

# %%
plt.figure(figsize=(7,7))
plt.scatter(x_test,y_test ,color= "Black")
plt.plot(x_test, y_pred, color="Green")

# %% [markdown]
# **Multiple Linear Regression:**
#
# ---

# %%
#Multiple Linear regression
#select the variables (x-FUELCONSUMPTION_HWY , y - CO2EMISSIONS)

x_variable1 = ['High','Low','Close' ] 
y_variable1 = ['Volume'] 

len(x_variable1)
#reshape variable
x1 = dataset[x_variable1].values.reshape(-1,3) # 1st value is -1, next value is the length of x_variable
y1 = dataset[y_variable1].values.reshape(-1,1)
print(x1.shape)
print(y1.shape)
#(or)
# Out:
# (102, 3)
# (102, 1)

# %%
#split the dataset
x_train1, x_test1, y_train1, y_test1 =  train_test_split(x1, y1, test_size = 0.2) # 80% for train, 20% for testing
print(x_train1.shape)
print(x_test1.shape)
# Out:
# (81, 3)
# (21, 3)

# %%
#build a model(multipleLinear)
Lin_reg1 = LinearRegression()

# %%
#training
model1 = Lin_reg1.fit(x_train1, y_train1)

# y_hat = Q_0(intercept) + Q_1(slope) * FUELCONSUMPTION_HWY'+ Q_2*'ENGINESI

# %%
# Make predictions using the testing set
y_pred1 = model1.predict(x_test1)

# %%
# The coefficients / slope
print('Coefficients / slope : \n',model1.coef_)
# Out:
# Coefficients / slope :
#  [[ 23771374.97222248 -26159373.72882806   1761311.39219859]]

# %%
# The mean squared error
print('Mean squared error: %.2f' % mean_squared_error(y_test1,y_pred1))
# Out:
# Mean squared error: 339216808816248.88

# %%
# Mean Absolute Error

print("Mean absolute Error : %.2f" % mean_absolute_error(y_test1,y_pred1))
# Out:
# Mean absolute Error : 12597460.37

# %%
# The coefficient of determination: 1 is perfect prediction  R^2
print('R^2 = %.2f' % r2_score(y_test1,y_pred1))
# Out:
# R^2 = 0.67

# %% [markdown]
# **Graph For Multiple Regression**
#
# ---

# %%
plt.figure(figsize=(7,7))
plt.scatter(y_test1,y_pred1 ,color= "Blue")
# plt.scatter(y_test1, x_test1, color ="Blue")
plt.plot(y_test, y_pred1, color = "Red")


plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs. Predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs. Predicted')

# %%
# pred_y_df = pd.DataFrame({'Actual Value' : y_test1,'Predicted Value' : y_pred1,'Difference' : y_test1 - y_pred1})
# pred_y_df[0:20]

# %%
plt.style.use('default')
plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(7, 3.5))

ax.plot(x_test1, y_pred1, color='k', label='Regression model')
ax.scatter(x, y, edgecolor='k', facecolor='blue', alpha=0.7, label='Sample data')
ax.set_ylabel('Vplume', fontsize=14)
ax.set_xlabel("'High','Low','Close'", fontsize=14)
ax.legend(facecolor='white', fontsize=11)
ax.text(0.55, 0.15, '$y = %.2f x_1 - %.2f $' % (model.coef_[0], abs(model.intercept_)), fontsize=10, transform=ax.transAxes)

fig.tight_layout()

# %% [markdown]
# ,'
